# %% [markdown]
# <a href="https://colab.research.google.com/github/marcelozanchetta/PGC302B/blob/main/PGC302B_Lista_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Lista de Exercícios 2
#
# ## Compressão
#
# 1. Baseado nos arquivos (imagem, áudio e vídeo) dos conjuntos de dados já utilizados em nosso curso escreva um pseudocódigo que calcule a entropia de primeira ordem para tratar strings. Avalie uma string "O dia está chuvoso".
#
# 2. Considere uma linha de 8 pixels de dados de intensidade, {108,139, 135, 244, 172, 173, 56, 99}. Se ela for uniformemente quantizada com precisão de 4 bits, calcule o erro rms e as relações sinal-ruído rms para os dados quantizados.
#
# 3. Sabendo que a codificação de vídeo busca reduzir as informações redundantes presentes no vídeo, caracterize os seguintes tipos de redundância, justificando a sua aplicabilidade na compressão de vídeo.
#
#   (a) Redundância Espacial
#
#   (b) Redundância Temporal
#
#   (c) Redundância Psicovisual
#
#   (d) Redundância de Codificação (entrópica).
#
# 4. Em que consiste a técnica de Compensação/Estimação de Movimento utilizada na Compressão de Vídeo?
#
# 5. Os procedimentos de codificação de comprimento variável podem ser usados para compactar uma imagem equalizada por histograma com 2n níveis de intensidade? Explique.
#
# 6. Qual a operação realizada pela Transformada Discreta do Cosseno na  compressão de Vídeo? A DCT não reduz diretamente o número de bits requerido em um bloco, então como se justifica o seu uso na compressão do vídeo? Esta transformação introduz perda no processo de compressão?
#
# 7. Supondo que tenha 8 caracteres com a seguinte distribuição A:(1), B:(1), C:(1), D:(2), E:(3), F:(5), G:(5), H:(10). Desenhe um árvore de Huffman de sua distribuição.
#
# 8. Qual o valor de entropia para a matriz abaixo em que os números (0, 20, 50 e 99) são os valores de níveis de cinza?
#
#   ![image.png](data:image/png;base64,...)
#
#   (a) Mostre passo a passo como construir a árvore de Huffman para codificar esses valores de cinza. Mostre o resultado da compressão com essa técnica.
#
#   (b) Qual será o número médio de bits necessario para cada pixel usando o código de Huffman?
#
# 9. Explique as vantagens e desvantagens em se usar blocos de tamanho diferentes do 8 x 8 pixels no cálculo da transformadas DCT na padronização JPEG.
#
# 10. Existe algum campo nos cabeçalhos do MPEG-1 que informe ao receptor qual a duração total da sequência (em segundos, ou em número de quadros) ?
#
# 11. Por que o padrão MPEG-2 introduziu o padrão alternado de reordenação de coeficientes? Em que situação é mais vantajoso do que o ziguezague?
#
# 12. Explique as vantagens e desvantagens em se usar blocos de tamanho diferentes do 8 x 8 pixels no cálculo da transformadas DCT na padronização JPEG.
#
# 13. Encontre o código usando RLE (Codificação Run Length) para a seguinte sequência de bits: 000000100100010010010011000000000. Qual a taxa de compressão desse código?
#
# 14. Usando o software GIMP, quantize e dequantize uma imagem RGB usando a regra e as tabelas JPEG para os formatos de amostragem 4:2:0 e 4:2:2 e explique a natureza do artefato de bloco. Ele é diferente da imagem de intensidade correspondente? A cor altera a percepção?
#
# 15. Qual é a diferença entre a codificação sequencial e a codificação progressiva no JPEG?
#
# 16. Uma fonte emite letras de um alfabeto A = {a1 , a2, a3, a4, a5} com probabilidades P(a1) = 0,15, P(a2) = 0,04, P(a3) = 0,26, P(a4) = 0,05 e P(a5) = 0,50.
#
#   (a) Calcule a entropia dessa fonte.
#
#   (b) Encontre um código Huffman para essa fonte.
